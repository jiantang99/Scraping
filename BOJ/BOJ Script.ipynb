# %%
from bs4 import BeautifulSoup
import urllib.request,sys,time
import requests
import pandas as pd
import re
import math
import os
from datetime import datetime

# %%
url = 'https://www.boj.or.jp/en/whatsnew/index.htm'
page = requests.get(url)
soup = BeautifulSoup(page.text, "html.parser")
aa = soup.find_all('li', class_='news_list-li')

monthDict = {	1:'Janauary',
		2:'February',
		3:'March',
		4:'April',
		5:'May',
		6:'June',
		7:'July',
		8:'August',
		9:'September',
		10:'October',
		11:'November',
		12:'December'		}

month = monthDict[datetime.now().month]
year = str(datetime.now().year)

combined = list()
titles = list()
links= list()
dates = list()

for a in aa:
    text = a.find('time',class_='time').text
    if month in text and year in text:
        combined.append(a)
      
for b in combined:
    titles.append(b.find('a').text)
    print(b.find('a').text)
    links.append(b.find('a',href=True)['href'])
    dates.append(b.find('time',class_='time').text)

# d = {'Title': titles,'Link': links, 'Date':dates}
# df = pd.DataFrame(data=d)
# df.to_csv(r'C:\Users\65936\\OneDrive\Desktop\MAS\\BOJ.csv')
# Out:
# Flow of Funds Accounts (Retroactive Revision and 1st Quarter 2023, Preliminary Figures)
# Summary of Opinions at the Monetary Policy Meeting on June 15 and 16, 2023[PDF 319KB]
# Services Producer Price Index (May)[PDF 239KB]
# Japanese Government Bonds Held by the Bank of Japan[XLSX 28KB]
# T-Bills Purchased by the Bank of Japan[XLSX 17KB]
# Bank of Japan Accounts (June 20)
# Minutes of the Monetary Policy Meeting on April 27 and 28, 2023[PDF 484KB]
# Statistics on Securities Financing Transactions in Japan (May 2023)
# Developments in Real Exports and Real Imports
# Each Category's Amount Outstanding of the Interest Scheme to Promote Lending (April 2023)[PDF 77KB]
# The Results of BIS International Locational Banking Statistics and International Consolidated Banking Statistics in Japan (end-Mar. 2023)
# (Research Paper) Heterogeneity and Wage Growth of Full-time Workers in Japan: An Empirical Analysis Using Micro Data
# BOJ Current Account Balances by Sector (May)[XLSX 39KB]
# Amendment to "Principal Terms and Conditions of Complementary Deposit Facility"[PDF 108KB]
# Statement on Monetary Policy[PDF 373KB]
# Loan Disbursement under the Fund-Provisioning Measure to Stimulate Bank Lending(June 2023)[PDF 21KB]
# Japanese Government Bonds Held by the Bank of Japan[XLSX 28KB]
# T-Bills Purchased by the Bank of Japan[XLSX 17KB]
# NGFS publishes the "NGFS Survey on Climate Scenarios - Key findings"
# Bank of Japan Accounts (June 10)
# Basic Figures on Fails (May)[PDF 288KB]
# Corporate Goods Price Index (May)[PDF 205KB]
# Average Contract Interest Rates on Loans and Discounts (Apr.)[PDF 148KB]
# Review of the Benchmark Ratio Used to Calculate the Macro Add-on Balance in Current Account Balances at the Bank of Japan[PDF 186KB]
# Money Stock (May)[PDF 146KB]
# Revision of Figures for the "International Investment Position of Japan (Quarterly Data)"
# Principal Figures of Financial Institutions (May)[PDF 235KB]
# Fifth Meeting of the Cross-Industry Forum on Interest Rate Benchmarks
# Amounts Outstanding in the Call Money Market (May)[XLSX 34KB]
# Consumption Activity Index
# Market Operations by the Bank of Japan (May)[XLSX 99KB]
# Monetary Base and the Bank of Japan's Transactions (May)[PDF 133KB]
# Bank of Japan's Transactions with the Government (May)[PDF 91KB]
# Sources of Changes in Current Account Balances (Projections for June)[XLSX 17KB]
# Japanese Government Bonds Held by the Bank of Japan[XLSX 28KB]
# T-Bills Purchased by the Bank of Japan[XLSX 17KB]
# Collateral Accepted by the Bank of Japan (End of May)[XLSX 17KB]
# Financial System Report Annex "Regional and Shinkin Banks' Recent Efforts to Address Climate Change"
# Bank of Japan Accounts (May 31)
# Monetary Base (May)
# Bond Market Survey (May 2023)[PDF 160KB]
# Sources of Changes in Current Account Balances and Market Operations (May)[XLSX 28KB]
# Summary of Opinions at the Monetary Policy Meeting on June 15 and 16, 2023[PDF 319KB]
# Minutes of the Monetary Policy Meeting on April 27 and 28, 2023[PDF 484KB]
# Each Category's Amount Outstanding of the Interest Scheme to Promote Lending (April 2023)[PDF 77KB]
# Amendment to "Principal Terms and Conditions of Complementary Deposit Facility"[PDF 108KB]
# Statement on Monetary Policy[PDF 373KB]
# Loan Disbursement under the Fund-Provisioning Measure to Stimulate Bank Lending(June 2023)[PDF 21KB]
# Review of the Benchmark Ratio Used to Calculate the Macro Add-on Balance in Current Account Balances at the Bank of Japan[PDF 186KB]
# Flow of Funds Accounts (Retroactive Revision and 1st Quarter 2023, Preliminary Figures)
# Services Producer Price Index (May)[PDF 239KB]
# Japanese Government Bonds Held by the Bank of Japan[XLSX 28KB]
# T-Bills Purchased by the Bank of Japan[XLSX 17KB]
# Bank of Japan Accounts (June 20)
# Statistics on Securities Financing Transactions in Japan (May 2023)
# The Results of BIS International Locational Banking Statistics and International Consolidated Banking Statistics in Japan (end-Mar. 2023)
# BOJ Current Account Balances by Sector (May)[XLSX 39KB]
# Japanese Government Bonds Held by the Bank of Japan[XLSX 28KB]
# T-Bills Purchased by the Bank of Japan[XLSX 17KB]
# Bank of Japan Accounts (June 10)
# Basic Figures on Fails (May)[PDF 288KB]
# Average Contract Interest Rates on Loans and Discounts (Apr.)[PDF 148KB]
# Corporate Goods Price Index (May)[PDF 205KB]
# Money Stock (May)[PDF 146KB]
# Revision of Figures for the "International Investment Position of Japan (Quarterly Data)"
# Principal Figures of Financial Institutions (May)[PDF 235KB]
# Amounts Outstanding in the Call Money Market (May)[XLSX 34KB]
# Market Operations by the Bank of Japan (May)[XLSX 99KB]
# Monetary Base and the Bank of Japan's Transactions (May)[PDF 133KB]
# Bank of Japan's Transactions with the Government (May)[PDF 91KB]
# Sources of Changes in Current Account Balances (Projections for June)[XLSX 17KB]
# Japanese Government Bonds Held by the Bank of Japan[XLSX 28KB]
# T-Bills Purchased by the Bank of Japan[XLSX 17KB]
# Collateral Accepted by the Bank of Japan (End of May)[XLSX 17KB]
# Bank of Japan Accounts (May 31)
# Monetary Base (May)
# Sources of Changes in Current Account Balances and Market Operations (May)[XLSX 28KB]
# (Research Paper) Heterogeneity and Wage Growth of Full-time Workers in Japan: An Empirical Analysis Using Micro Data
# Financial System Report Annex "Regional and Shinkin Banks' Recent Efforts to Address Climate Change"
# Developments in Real Exports and Real Imports
# NGFS publishes the "NGFS Survey on Climate Scenarios - Key findings"
# Fifth Meeting of the Cross-Industry Forum on Interest Rate Benchmarks
# Consumption Activity Index
# Bond Market Survey (May 2023)[PDF 160KB]

# %%
url = 'https://www.boj.or.jp/en/whatsnew/index.htm'
page = requests.get(url)
soup = BeautifulSoup(page.text, "html.parser")
aa = soup.find_all('li', class_='news_list-li')
combined_list=list()

baseLink = 'https://www.boj.or.jp'

titles_list= list()
links_list= list()
dates_list= list()

for a in aa:
    text = a.find('time',class_='time').text
    if 'June' in text and '2023' in text:
        combined_list.append(a)

for b in combined_list:
    titles_list.append(b.find('a').text)
    fullLink = baseLink + b.find('a',href=True)['href']
    links_list.append(fullLink)
    dates_list.append(b.find('time',class_='time').text)
    
listZip = list(zip(titles_list, links_list, dates_list))
    
for t,l,d in list(dict.fromkeys(listZip)):
    print(t)
    print(l)
    print(d)
# Out:
# Quarterly Schedule of Outright Purchases of Japanese Government Bonds (Competitive Auction Method) (July-September 2023)[PDF 97KB]
# https://www.boj.or.jp/en/mopo/mpmdeci/mpr_2023/mpr230630c.pdf
# June 30, 2023
# Timetable and Schedule of U.S. Dollar Funds-Supplying Operations (July-September 2023)[PDF 55KB]
# https://www.boj.or.jp/en/mopo/mpmdeci/mpr_2023/mpr230630b.pdf
# June 30, 2023
# Schedules of Outright Purchases of CP and Corporate Bonds (July-August 2023)[PDF 49KB]
# https://www.boj.or.jp/en/mopo/mpmdeci/mpr_2023/mpr230630a.pdf
# June 30, 2023
# (Research Paper) Results of the Second Market Functioning Survey concerning Climate Change
# https://www.boj.or.jp/en/research/brp/ron_2023/ron230630a.htm
# June 30, 2023
# Payment and Settlement Statistics (May)[PDF 421KB]
# https://www.boj.or.jp/en/statistics/set/kess/release/2023/kess2305.pdf
# June 30, 2023
# Liquidity Indicators in the JGB Markets (May)[PDF 931KB]
# https://www.boj.or.jp/en/paym/bond/ryudo.pdf
# June 29, 2023
# Speech by Board Member NOGUCHI in Okinawa on June 22, 2023 (Economic Activity, Prices, and Monetary Policy in Japan)
# https://www.boj.or.jp/en/about/release_2023/rel230629a.htm
# June 29, 2023
# Average Contract Interest Rates on Loans and Discounts (May)[PDF 148KB]
# https://www.boj.or.jp/en/statistics/dl/loan/yaku/yaku2305.pdf
# June 29, 2023
# Assets and Liabilities of Domestically Licensed Banks (Banking Accounts) (End of May)[PDF 424KB]
# https://www.boj.or.jp/en/statistics/asli_fi/ald2305.pdf
# June 29, 2023
# Issuance Schedule for the New Series of Bank of Japan Notes
# https://www.boj.or.jp/en/note_tfjgs/note/related/note230628a.htm
# June 28, 2023
# Speech by Board Member ADACHI in Kagoshima on June 21, 2023 (Economic Activity, Prices, and Monetary Policy in Japan)
# https://www.boj.or.jp/en/about/release_2023/rel230627a.htm
# June 27, 2023
# Minutes of the Seventeenth Round of the "Bond Market Group" Meetings (June 5-6, 2023)[PDF 155KB]
# https://www.boj.or.jp/en/paym/bond/mbond_list/mbond2306.pdf
# June 27, 2023
# Semiannual Report on Currency and Monetary Control (Summary)
# https://www.boj.or.jp/en/mopo/diet/d_report/hanki23a.htm
# June 27, 2023
# Measures of Underlying Inflation
# https://www.boj.or.jp/en/research/research_data/cpi/index.htm
# June 27, 2023
# Flow of Funds Accounts (Retroactive Revision and 1st Quarter 2023, Preliminary Figures)
# https://www.boj.or.jp/en/statistics/sj/sj.htm
# June 27, 2023
# Summary of Opinions at the Monetary Policy Meeting on June 15 and 16, 2023[PDF 319KB]
# https://www.boj.or.jp/en/mopo/mpmsche_minu/opinion_2023/opi230616.pdf
# June 26, 2023
# Services Producer Price Index (May)[PDF 239KB]
# https://www.boj.or.jp/en/statistics/pi/cspi_release/sppi2305.pdf
# June 26, 2023
# Japanese Government Bonds Held by the Bank of Japan[XLSX 28KB]
# https://www.boj.or.jp/en/statistics/boj/other/mei/release/2023/mei230620.xlsx
# June 22, 2023
# T-Bills Purchased by the Bank of Japan[XLSX 17KB]
# https://www.boj.or.jp/en/statistics/boj/other/tmei/release/2023/tmei230620.xlsx
# June 22, 2023
# Bank of Japan Accounts (June 20)
# https://www.boj.or.jp/en/statistics/boj/other/acmai/release/2023/ac230620.htm
# June 22, 2023
# Minutes of the Monetary Policy Meeting on April 27 and 28, 2023[PDF 484KB]
# https://www.boj.or.jp/en/mopo/mpmsche_minu/minu_2023/g230428.pdf
# June 21, 2023
# Statistics on Securities Financing Transactions in Japan (May 2023)
# https://www.boj.or.jp/en/statistics/bis/repo/index.htm
# June 21, 2023
# Developments in Real Exports and Real Imports
# https://www.boj.or.jp/en/research/research_data/reri/index.htm
# June 20, 2023
# Each Category's Amount Outstanding of the Interest Scheme to Promote Lending (April 2023)[PDF 77KB]
# https://www.boj.or.jp/en/mopo/measures/mkt_ope/oth_b/mope230620a.pdf
# June 20, 2023
# The Results of BIS International Locational Banking Statistics and International Consolidated Banking Statistics in Japan (end-Mar. 2023)
# https://www.boj.or.jp/en/statistics/bis/ibs/index.htm
# June 20, 2023
# (Research Paper) Heterogeneity and Wage Growth of Full-time Workers in Japan: An Empirical Analysis Using Micro Data
# https://www.boj.or.jp/en/research/wps_rev/wps_2023/wp23e11.htm
# June 19, 2023
# BOJ Current Account Balances by Sector (May)[XLSX 39KB]
# https://www.boj.or.jp/en/statistics/boj/other/cabs/cabs.xlsx
# June 16, 2023
# Amendment to "Principal Terms and Conditions of Complementary Deposit Facility"[PDF 108KB]
# https://www.boj.or.jp/en/mopo/mpmdeci/mpr_2023/mpr230616a.pdf
# June 16, 2023
# Statement on Monetary Policy[PDF 373KB]
# https://www.boj.or.jp/en/mopo/mpmdeci/mpr_2023/k230616a.pdf
# June 16, 2023
# Loan Disbursement under the Fund-Provisioning Measure to Stimulate Bank Lending(June 2023)[PDF 21KB]
# https://www.boj.or.jp/en/mopo/measures/mkt_ope/len_b/mope230615a.pdf
# June 15, 2023
# Japanese Government Bonds Held by the Bank of Japan[XLSX 28KB]
# https://www.boj.or.jp/en/statistics/boj/other/mei/release/2023/mei230609.xlsx
# June 13, 2023
# T-Bills Purchased by the Bank of Japan[XLSX 17KB]
# https://www.boj.or.jp/en/statistics/boj/other/tmei/release/2023/tmei230609.xlsx
# June 13, 2023
# NGFS publishes the "NGFS Survey on Climate Scenarios - Key findings"
# https://www.boj.or.jp/en/about/climate/cli230613a.htm
# June 13, 2023
# Bank of Japan Accounts (June 10)
# https://www.boj.or.jp/en/statistics/boj/other/acmai/release/2023/ac230610.htm
# June 13, 2023
# Basic Figures on Fails (May)[PDF 288KB]
# https://www.boj.or.jp/en/statistics/set/bffail/sjgb2305.pdf
# June 12, 2023
# Corporate Goods Price Index (May)[PDF 205KB]
# https://www.boj.or.jp/en/statistics/pi/cgpi_release/cgpi2305.pdf
# June 12, 2023
# Average Contract Interest Rates on Loans and Discounts (Apr.)[PDF 148KB]
# https://www.boj.or.jp/en/statistics/dl/loan/yaku/yaku2304.pdf
# June 12, 2023
# Review of the Benchmark Ratio Used to Calculate the Macro Add-on Balance in Current Account Balances at the Bank of Japan[PDF 186KB]
# https://www.boj.or.jp/en/mopo/mpmdeci/mpr_2023/mpr230609a.pdf
# June  9, 2023
# Money Stock (May)[PDF 146KB]
# https://www.boj.or.jp/en/statistics/money/ms/ms2305.pdf
# June  9, 2023
# Revision of Figures for the "International Investment Position of Japan (Quarterly Data)"
# https://www.boj.or.jp/en/statistics/outline/notice_2023/not230608a.htm
# June  8, 2023
# Principal Figures of Financial Institutions (May)[PDF 235KB]
# https://www.boj.or.jp/en/statistics/dl/depo/kashi/kasi2305.pdf
# June  8, 2023
# Fifth Meeting of the Cross-Industry Forum on Interest Rate Benchmarks
# https://www.boj.or.jp/en/paym/market/i_forum/ifo230607a.htm
# June  7, 2023
# Market Operations by the Bank of Japan (May)[XLSX 99KB]
# https://www.boj.or.jp/en/statistics/boj/fm/ope/m_release/2023/ope2305.xlsx
# June  7, 2023
# Monetary Base and the Bank of Japan's Transactions (May)[PDF 133KB]
# https://www.boj.or.jp/en/statistics/boj/other/mbt/mbt2305.pdf
# June  7, 2023
# Bank of Japan's Transactions with the Government (May)[PDF 91KB]
# https://www.boj.or.jp/en/statistics/boj/other/tseifu/release/2023/seifu2305.pdf
# June  7, 2023
# Sources of Changes in Current Account Balances (Projections for June)[XLSX 17KB]
# https://www.boj.or.jp/en/statistics/boj/fm/juqp/juqp2306.xlsx
# June  5, 2023
# Japanese Government Bonds Held by the Bank of Japan[XLSX 28KB]
# https://www.boj.or.jp/en/statistics/boj/other/mei/release/2023/mei230531.xlsx
# June  2, 2023
# T-Bills Purchased by the Bank of Japan[XLSX 17KB]
# https://www.boj.or.jp/en/statistics/boj/other/tmei/release/2023/tmei230531.xlsx
# June  2, 2023
# Collateral Accepted by the Bank of Japan (End of May)[XLSX 17KB]
# https://www.boj.or.jp/en/statistics/boj/other/col/col2305.xlsx
# June  2, 2023
# Financial System Report Annex "Regional and Shinkin Banks' Recent Efforts to Address Climate Change"
# https://www.boj.or.jp/en/research/brp/fsr/fsrb230602.htm
# June  2, 2023
# Bank of Japan Accounts (May 31)
# https://www.boj.or.jp/en/statistics/boj/other/acmai/release/2023/ac230531.htm
# June  2, 2023
# Bond Market Survey (May 2023)[PDF 160KB]
# https://www.boj.or.jp/en/paym/bond/bond_list/bond2305.pdf
# June  1, 2023
# Sources of Changes in Current Account Balances and Market Operations (May)[XLSX 28KB]
# https://www.boj.or.jp/en/statistics/boj/fm/juqf/juqf05.xlsx
# June  1, 2023
