# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import pandas as pd 
import os
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

# %%
url = "https://www.bankofengland.co.uk/news/prudential-regulation"

# Set up the Selenium driver
driver = webdriver.Chrome()

driver.get(url)
driver.implicitly_wait(5)
button = driver.find_element(By.XPATH,"//button[contains(@class,'cookie__button btn btn-default btn-neutral')]")
button.click()
driver.implicitly_wait(5)

# Get HTML code
html = driver.page_source

soup = BeautifulSoup(html, 'html.parser')
div_element = soup.find_all('div', class_='col3')
driver.close()
for a in div_element:
    if a.find('time',class_='release-date') is not None:
        if 'July' in a.find('time',class_='release-date').text and '2023' in a.find('time',class_='release-date').text:
            print(a.find('h3',class_='list exclude-navigation'))
            print(a.find('a',href=True)['href'])
            print(a.find('time',class_='release-date'))
# Out:
# title
# <h3 class="list exclude-navigation" itemprop="name">Prudential Regulation Authority Annual Report 2022/23</h3>
# link
# /prudential-regulation/publication/2023/july/pra-annual-report-2022-23
# date
# <time class="release-date" datetime="2023-07-06" itemprop="datePublished">
#                             06 July 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">The Prescribed Persons (Reports on Disclosures of Information) Regulations 2017 - Annual Report 2022/23</h3>
# link
# /prudential-regulation/publication/2023/july/prescribed-persons-regulations-2017-annual-report-2022-23
# date
# <time class="release-date" datetime="2023-07-06" itemprop="datePublished">
#                             06 July 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">Enforcement Decision Making Committee: 2022/23 Report</h3>
# link
# /prudential-regulation/publication/2023/july/enforcement-decision-making-committee-2022-23-report
# date
# <time class="release-date" datetime="2023-07-06" itemprop="datePublished">
#                             06 July 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">PRA Regulatory Digest - June 2023</h3>
# link
# /prudential-regulation/regulatory-digest/2023/june
# date
# <time class="release-date" datetime="2023-07-03" itemprop="datePublished">
#                             03 July 2023
#                         </time>

# %%
for a in div_element:
    if a.find('time',class_='release-date') is not None:
        print('title')
        print(a.find('h3',class_='list exclude-navigation'))
        print('link')
        print(a.find('a',href=True)['href'])
        print('date')
        
        print(a.find('time',class_='release-date'))
# Out:
# title
# <h3 class="list exclude-navigation" itemprop="name">Prudential Regulation Authority Annual Report 2022/23</h3>
# link
# /prudential-regulation/publication/2023/july/pra-annual-report-2022-23
# date
# <time class="release-date" datetime="2023-07-06" itemprop="datePublished">
#                             06 July 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">The Prescribed Persons (Reports on Disclosures of Information) Regulations 2017 - Annual Report 2022/23</h3>
# link
# /prudential-regulation/publication/2023/july/prescribed-persons-regulations-2017-annual-report-2022-23
# date
# <time class="release-date" datetime="2023-07-06" itemprop="datePublished">
#                             06 July 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">Enforcement Decision Making Committee: 2022/23 Report</h3>
# link
# /prudential-regulation/publication/2023/july/enforcement-decision-making-committee-2022-23-report
# date
# <time class="release-date" datetime="2023-07-06" itemprop="datePublished">
#                             06 July 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">PRA Regulatory Digest - June 2023</h3>
# link
# /prudential-regulation/regulatory-digest/2023/june
# date
# <time class="release-date" datetime="2023-07-03" itemprop="datePublished">
#                             03 July 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">PS7/23 – Depositor Protection</h3>
# link
# /prudential-regulation/publication/2023/june/depositor-protection
# date
# <time class="release-date" datetime="2023-06-30" itemprop="datePublished">
#                             30 June 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">CP11/23 – PRA statement on the review of rules</h3>
# link
# /prudential-regulation/publication/2023/june/review-of-rules
# date
# <time class="release-date" datetime="2023-06-30" itemprop="datePublished">
#                             30 June 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">Deposit Guarantee Scheme</h3>
# link
# /prudential-regulation/publication/2015/deposit-guarantee-scheme
# date
# <time class="release-date" datetime="2023-06-30" itemprop="datePublished">
#                             30 June 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">PS8/23 – Regulated fees and levies: Rates proposals 2023/24</h3>
# link
# /prudential-regulation/publication/2023/june/regulated-fees-and-levies-rates-proposals-2023-24
# date
# <time class="release-date" datetime="2023-06-29" itemprop="datePublished">
#                             29 June 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">CP12/23 - Review of Solvency II: Adapting to the UK insurance market</h3>
# link
# /prudential-regulation/publication/2023/june/review-of-solvency-ii-adapting-to-the-uk-insurance-market
# date
# <time class="release-date" datetime="2023-06-29" itemprop="datePublished">
#                             29 June 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">CP10/23 – Solvent exit planning for non-systemic banks and building societies</h3>
# link
# /prudential-regulation/publication/2023/june/solvent-exit-planning-for-non-systemic-banks-and-building-societies
# date
# <time class="release-date" datetime="2023-06-28" itemprop="datePublished">
#                             28 June 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">Follow up to the letter: Insights from PRA thematic review of general insurance reserving and capital...</h3>
# link
# /prudential-regulation/letter/2023/june/insights-from-thematic-review
# date
# <time class="release-date" datetime="2023-06-23" itemprop="datePublished">
#                             23 June 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">Results of the firm feedback survey 2022</h3>
# link
# /prudential-regulation/publication/2023/june/results-of-the-firm-feedback-survey-2022
# date
# <time class="release-date" datetime="2023-06-23" itemprop="datePublished">
#                             23 June 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">Letter from Charlotte Gerken ‘Feedback on the PRA’s preliminary thematic review work on funded reinsurance...</h3>
# link
# /prudential-regulation/letter/2023/june/thematic-review-work-on-funded-reinsurance-arrangements
# date
# <time class="release-date" datetime="2023-06-15" itemprop="datePublished">
#                             15 June 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">PRA Regulatory Digest - May 2023</h3>
# link
# /prudential-regulation/regulatory-digest/2023/may
# date
# <time class="release-date" datetime="2023-06-01" itemprop="datePublished">
#                             01 June 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">SS1/23 – Model risk management principles for banks</h3>
# link
# /prudential-regulation/publication/2023/may/model-risk-management-principles-for-banks-ss
# date
# <time class="release-date" datetime="2023-05-17" itemprop="datePublished">
#                             17 May 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">PS6/23 – Model risk management principles for banks</h3>
# link
# /prudential-regulation/publication/2023/may/model-risk-management-principles-for-banks
# date
# <time class="release-date" datetime="2023-05-17" itemprop="datePublished">
#                             17 May 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">PS5/23 – Risks from contingent leverage</h3>
# link
# /prudential-regulation/publication/2023/may/risks-from-contingent-leverage
# date
# <time class="release-date" datetime="2023-05-11" itemprop="datePublished">
#                             11 May 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">PS4/23 - Moving Senior Managers Regime forms from the PRA Rulebook</h3>
# link
# /prudential-regulation/publication/2023/may/moving-senior-managers-regime-forms
# date
# <time class="release-date" datetime="2023-05-09" itemprop="datePublished">
#                             09 May 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">CP9/23 – The Bank of England’s approach to enforcement: proposed changes and clarifications</h3>
# link
# /prudential-regulation/publication/2023/may/enforcement
# date
# <time class="release-date" datetime="2023-05-04" itemprop="datePublished">
#                             04 May 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">PRA Regulatory Digest - April 2023</h3>
# link
# /prudential-regulation/regulatory-digest/2023/april
# date
# <time class="release-date" datetime="2023-05-02" itemprop="datePublished">
#                             02 May 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">Prudential Regulation Authority Business Plan 2023/24</h3>
# link
# /prudential-regulation/publication/2023/may/pra-business-plan-2023-24
# date
# <time class="release-date" datetime="2023-05-02" itemprop="datePublished">
#                             02 May 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">CP8/23 – Occasional consultation paper – April 2023</h3>
# link
# /prudential-regulation/publication/2023/april/occasional-consultation-paper-april-2023
# date
# <time class="release-date" datetime="2023-04-27" itemprop="datePublished">
#                             27 April 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">CP7/23 – Regulated fees and levies: Rates proposals 2023/24</h3>
# link
# /prudential-regulation/publication/2023/april/regulated-fees-and-levies-rates-proposals-2023-24
# date
# <time class="release-date" datetime="2023-04-13" itemprop="datePublished">
#                             13 April 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">Critical third parties to the UK financial sector – third party survey</h3>
# link
# /prudential-regulation/publication/2023/april/critical-third-parties-to-the-uk-financial-sector-third-party-survey
# date
# <time class="release-date" datetime="2023-04-11" itemprop="datePublished">
#                             11 April 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">FS1/23 – The prudential liquidity framework: Supporting liquid asset usability</h3>
# link
# /prudential-regulation/publication/2023/april/prudential-liquidity-framework-supporting-liquid-asset-usability
# date
# <time class="release-date" datetime="2023-04-03" itemprop="datePublished">
#                             03 April 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">PRA Regulatory Digest - March 2023</h3>
# link
# /prudential-regulation/regulatory-digest/2023/march
# date
# <time class="release-date" datetime="2023-04-03" itemprop="datePublished">
#                             03 April 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">PS2/23 – Depositor Protection</h3>
# link
# /prudential-regulation/publication/2023/march/depositor-protection
# date
# <time class="release-date" datetime="2023-03-31" itemprop="datePublished">
#                             31 March 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">PS3/23 – Financial Services Compensation Scheme – Management Expenses Levy Limit 2023/24</h3>
# link
# /prudential-regulation/publication/2023/march/financial-services-compensation-scheme-management-expenses-levy-limit-2023-2024
# date
# <time class="release-date" datetime="2023-03-31" itemprop="datePublished">
#                             31 March 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">DP1/23 – Review of the Senior Managers and Certification Regime (SM&amp;CR)</h3>
# link
# /prudential-regulation/publication/2023/march/review-of-the-senior-managers-and-certification-regime
# date
# <time class="release-date" datetime="2023-03-30" itemprop="datePublished">
#                             30 March 2023
#                         </time>
# title
# <h3 class="list exclude-navigation" itemprop="name">Thematic findings from the 2022 cyber stress test</h3>
# link
# /prudential-regulation/letter/2023/thematic-findings-2022-cyber-stress-test
# date
# <time class="release-date" datetime="2023-03-29" itemprop="datePublished">
#                             29 March 2023
#                         </time>
